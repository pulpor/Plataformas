# %% [markdown]
# <a href="https://colab.research.google.com/github/pulpor/ebac/blob/main/Exerc%C3%ADcio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 1

# %%
print ('Olá mundo!') sdfsdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercício 2

# %%
total1 = ''
total2 = 834.47
total3 = 15378.12 

venda1 = 3
venda2 = ''
venda3 = 5

media1 = 320.52
media2 = 119.21 
media3 = ''

total1 = venda1 * media1
venda1 = total1 / media1
media1 = total1 / venda1

print (total1)
print (venda1)
print (media1)

venda2 = total2 / media2
total2 = venda2 * media2
media2 = total2 / venda2

print (total2)
print (venda2)
print (media2)

media3 = total3 / venda3
total3 = venda3 * media3
venda3 = total3 / media3

print (total3)
print (venda3)
print (media3)

# %% [markdown]
# # Exercício 3

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print (cancao.upper());
print (cancao.lower());
print (cancao.capitalize());
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# roda mundo, roda gigante, roda moinho, roda pião.
# Roda mundo, roda gigante, roda moinho, roda pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

selic = (noticia[12:17])
print (selic)

posicao = noticia.find('6')
# print (posicao)
ano = (noticia[62])
print (ano)
# Out:
# 2,75%
# 6

# %% [markdown]
# # Exercícios 4

# %%
a = False
b = True
x = not a & b

print ( a | a )
print ( a | b )
print ( b | a )
print ( b | b )
print ( ' ' )
print ( a & a )
print ( a & b ) #False
print ( b & a )
print ( b & b )
print ( ' ' )
print ( not a ) 
print (not b )
print ( ' ' )
print ( not a & b )   #Inverte
print ( x )
# Out:
# False
# True
# True
# True
#
# False
# False
# False
# True
#
# True
# False
#
# True
# True
