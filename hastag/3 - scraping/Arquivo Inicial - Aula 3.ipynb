# %% [markdown]
# # Automação Web e Busca de Informações com Python
#
# #### Desafio:
#
# Trabalhamos em uma importadora e o preço dos nossos produtos é vinculado a cotação de:
# - Dólar
# - Euro
# - Ouro
#
# Precisamos pegar na internet, de forma automática, a cotação desses 3 itens e saber quanto devemos cobrar pelos nossos produtos, considerando uma margem de contribuição que temos na nossa base de dados.
#
# Base de Dados: https://drive.google.com/drive/folders/1KmAdo593nD8J9QBaZxPOG1yxHZua4Rtv?usp=sharing
#
# Para isso, vamos criar uma automação web:
#
# - Usaremos o selenium
# - Importante: baixar o webdriver

# %%
#1 - pegar as cotações
#2 - importar a base de dados e atualiza-la
#3 - recalcular os preços
#4 - exportar a base atualizada

# %%
#'pyautogui' controla mouse e teclado, já o 'selenium' controla o navegador

# !pip install selenium
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

navegador = webdriver.Chrome()   #abrir o chrome


#1 - pegar as cotações

navegador.get("https://www.google.com/")    #abrir o google


#copiar o xpath (inspecionar elemento) / xpatch é o elemento da pagina e nao a informação contida nela

navegador.find_element('xpath', '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação dolar")
navegador.find_element('xpath', '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)

#pegar o elemento que tráz a cotação
cotacaoDolar = navegador.find_element('xpath', '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')

print(cotacaoDolar)


navegador.get("https://www.google.com/")    #abrir o google


#copiar o xpath (inspecionar elemento) / xpatch é o elemento da pagina e nao a informação contida nela

navegador.find_element('xpath', '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação euro")
navegador.find_element('xpath', '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)

#pegar o elemento que tráz a cotação
cotacaoEuro = navegador.find_element('xpath', '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')

print(cotacaoEuro)


navegador.get("https://www.melhorcambio.com/ouro-hoje") 

cotacaoOuro = navegador.find_element('xpath', '//*[@id="comercial"]').get_attribute('value')

cotacaoOuro = cotacaoOuro.replace(",",".")


print(cotacaoOuro)


#os () vazios são comandos que tem de fazer uma ação, executar algo
navegador.quit()  #fecha navegador
# Out:
# 5.16
# 5.556675
# 311.97

# %%
# !pip install pandas
# !pip install openpyxp
# !pip install numpy
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# ...

# %%
import pandas as pd 

tabela = pd.read_excel("Produtos.xlsx")
display(tabela)
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %%
#atributo 'loc' é de localizar
#float é pra transformar a formatação de texto em numeros decimais
#tabela.loc[linha, coluna]

#tabela["Moeda"] == "Dólar"   /  todas as linhas que a coluna moeda for igual a dolar

tabela.loc[tabela["Moeda"] == "Dólar", "Cotação"] = float(cotacaoDolar)
tabela.loc[tabela["Moeda"] == "Euro", "Cotação"] = float(cotacaoEuro)
tabela.loc[tabela["Moeda"] == "Ouro", "Cotação"] = float(cotacaoOuro)

display(tabela)
# Out:
#          Produtos  Preço Original  Moeda     Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    5.160000          4999.95    1.40
# 1   Carro Renault         4500.00   Euro    5.556675         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar    5.160000          4499.95    1.70
# 3          IPhone          799.00  Dólar    5.160000          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro    5.556675         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar    5.160000          2402.40    2.00
# 6        Joia 20g           20.00   Ouro  311.970000          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %%
# preço de compra = cotação * preço original
tabela["Preço de Compra"] = tabela["Cotação"] * tabela["Preço de Venda"]

# preço de venda = preço de compra * margens
tabela["Preço de Venda"] = tabela["Preço de Compra"] * tabela["Margem"]

display(tabela)
# Out:
#          Produtos  Preço Original  Moeda     Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    5.160000     1.361685e+07    1.40
# 1   Carro Renault         4500.00   Euro    5.556675     4.118544e+08    2.00
# 2   Notebook Dell          899.99  Dólar    5.160000     2.664417e+07    1.70
# 3          IPhone          799.00  Dólar    5.160000     2.365436e+07    1.70
# 4      Carro Fiat         3000.00   Euro    5.556675     2.236387e+08    1.90
# 5  Celular Xiaomi          480.48  Dólar    5.160000     2.724985e+07    2.00
# 6        Joia 20g           20.00   Ouro  311.970000     1.159687e+14    1.15
#
#    Preço de Venda
# 0    1.906359e+07
# 1    8.237088e+08
# 2    4.529509e+07
# 3    4.021242e+07
# 4    4.249135e+08
# 5    5.449970e+07
# 6    1.333640e+14

# %% [markdown]
# ### Agora vamos atualiza a nossa base de preços com as novas cotações

# %% [markdown]
# - Importando a base de dados

# %%
#exportar para excell (sem o índice)
tabela.to_excel("Produtos Editados.xlsx", index=False)

# %% [markdown]
# - Atualizando os preços e o cálculo do Preço Final

# %% [markdown]
# ### Agora vamos exportar a nova base de preços atualizada
